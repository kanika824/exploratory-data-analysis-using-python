# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
train_df=pd.read_excel('/content/Data_Train.xlsx')
train_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
test_df=pd.read_excel('/content/Test_set.xlsx')
test_df.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info

# %%
final_df=train_df.merge(test_df)
final_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0  Jet Airways      18/05/2019     Delhi      Cochin  DEL → AMD → BOM → COK
# 1    Air India      27/06/2019     Delhi      Cochin  DEL → GOI → BOM → COK
# 2  Jet Airways      21/03/2019     Delhi      Cochin  DEL → BDQ → BOM → COK
# 3       IndiGo      03/03/2019  Banglore   New Delhi              BLR → DEL
# 4       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info  \
# 0    19:10  19:00 19 May  23h 50m     2 stops                      No info
# 1    22:00  19:15 28 Jun  21h 15m     2 stops                      No info
# 2    18:25  18:50 22 Mar  24h 25m     2 stops  In-flight meal not included
# 3    18:55         21:45   2h 50m    non-stop                      No info
# 4    00:40         03:25   2h 45m    non-stop                      No info
#
#    Price
# 0  15129
# 1  10441
# 2   9270
# 3   8855
# 4   4777

# %%
final_df.tail()
# Out:
#                Airline Date_of_Journey    Source Destination  \
# 268  Multiple carriers       6/06/2019     Delhi      Cochin
# 269          Air India      24/03/2019  Banglore   New Delhi
# 270          Air India       9/05/2019   Kolkata    Banglore
# 271          Air India       1/06/2019     Delhi      Cochin
# 272          Air India      24/03/2019   Kolkata    Banglore
#
#                      Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 268        DEL → BOM → COK    10:00         21:00      11h      1 stop
# 269              BLR → DEL    06:10         08:55   2h 45m    non-stop
# 270  CCU → BOM → GOI → BLR    16:50  05:35 10 May  12h 45m     2 stops
# 271  DEL → AMD → BOM → COK    16:40  19:15 02 Jun  26h 35m     2 stops
# 272  CCU → BOM → GOI → BLR    09:25  05:35 25 Mar  20h 10m     2 stops
#
#     Additional_Info  Price
# 268         No info   7933
# 269         No info   3758
# 270         No info  11432
# 271         No info   9863
# 272         No info  12352

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273 entries, 0 to 272
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          273 non-null    object
#  1   Date_of_Journey  273 non-null    object
#  2   Source           273 non-null    object
#  3   Destination      273 non-null    object
#  4   Route            273 non-null    object
#  5   Dep_Time         273 non-null    object
#  6   Arrival_Time     273 non-null    object
#  7   Duration         273 non-null    object
#  8   Total_Stops      273 non-null    object
#  9   Additional_Info  273 non-null    object
#  10  Price            273 non-null    int64
# dtypes: int64(1), object(10)
# memory usage: 23.6+ KB

# %%
## feature engineering process on date of journey
final_df['Date']=final_df['Date_of_Journey'].str.split('/').str[0]
final_df['Month']=final_df['Date_of_Journey'].str.split('/').str[1]
final_df['Year']=final_df['Date_of_Journey'].str.split('/').str[2]

# %%
final_df.head(2)
# Out:
#        Airline Date_of_Journey Source Destination                  Route  \
# 0  Jet Airways      18/05/2019  Delhi      Cochin  DEL → AMD → BOM → COK
# 1    Air India      27/06/2019  Delhi      Cochin  DEL → GOI → BOM → COK
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price Date  \
# 0    19:10  19:00 19 May  23h 50m     2 stops         No info  15129   18
# 1    22:00  19:15 28 Jun  21h 15m     2 stops         No info  10441   27
#
#   Month  Year
# 0    05  2019
# 1    06  2019

# %%
final_df['Date']=final_df['Date'].astype(int)
final_df['Month']=final_df['Month'].astype(int)
final_df['Year']=final_df['Year'].astype(int)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273 entries, 0 to 272
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          273 non-null    object
#  1   Date_of_Journey  273 non-null    object
#  2   Source           273 non-null    object
#  3   Destination      273 non-null    object
#  4   Route            273 non-null    object
#  5   Dep_Time         273 non-null    object
#  6   Arrival_Time     273 non-null    object
#  7   Duration         273 non-null    object
#  8   Total_Stops      273 non-null    object
#  9   Additional_Info  273 non-null    object
#  10  Price            273 non-null    int64
#  11  Date             273 non-null    int64
#  12  Month            273 non-null    int64
#  13  Year             273 non-null    int64
# dtypes: int64(4), object(10)
# memory usage: 30.0+ KB

# %%
final_df.drop('Date_of_Journey',axis=1,inplace=True)

# %%
final_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0  Jet Airways     Delhi      Cochin  DEL → AMD → BOM → COK    19:10
# 1    Air India     Delhi      Cochin  DEL → GOI → BOM → COK    22:00
# 2  Jet Airways     Delhi      Cochin  DEL → BDQ → BOM → COK    18:25
# 3       IndiGo  Banglore   New Delhi              BLR → DEL    18:55
# 4       IndiGo  Banglore   New Delhi              BLR → DEL    00:40
#
#    Arrival_Time Duration Total_Stops              Additional_Info  Price  \
# 0  19:00 19 May  23h 50m     2 stops                      No info  15129
# 1  19:15 28 Jun  21h 15m     2 stops                      No info  10441
# 2  18:50 22 Mar  24h 25m     2 stops  In-flight meal not included   9270
# 3         21:45   2h 50m    non-stop                      No info   8855
# 4         03:25   2h 45m    non-stop                      No info   4777
#
#    Date  Month  Year
# 0    18      5  2019
# 1    27      6  2019
# 2    21      3  2019
# 3     3      3  2019
# 4    24      3  2019

# %%
final_df['Arrival_Time'].str.split(' ').str[0]
# Out:
# 0      19:00
# 1      19:15
# 2      18:50
# 3      21:45
# 4      03:25
#        ...
# 268    21:00
# 269    08:55
# 270    05:35
# 271    19:15
# 272    05:35
# Name: Arrival_Time, Length: 273, dtype: object

# %%
final_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0  Jet Airways     Delhi      Cochin  DEL → AMD → BOM → COK    19:10
# 1    Air India     Delhi      Cochin  DEL → GOI → BOM → COK    22:00
# 2  Jet Airways     Delhi      Cochin  DEL → BDQ → BOM → COK    18:25
# 3       IndiGo  Banglore   New Delhi              BLR → DEL    18:55
# 4       IndiGo  Banglore   New Delhi              BLR → DEL    00:40
#
#    Arrival_Time Duration Total_Stops              Additional_Info  Price  \
# 0  19:00 19 May  23h 50m     2 stops                      No info  15129
# 1  19:15 28 Jun  21h 15m     2 stops                      No info  10441
# 2  18:50 22 Mar  24h 25m     2 stops  In-flight meal not included   9270
# 3         21:45   2h 50m    non-stop                      No info   8855
# 4         03:25   2h 45m    non-stop                      No info   4777
#
#    Date  Month  Year
# 0    18      5  2019
# 1    27      6  2019
# 2    21      3  2019
# 3     3      3  2019
# 4    24      3  2019

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273 entries, 0 to 272
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          273 non-null    object
#  1   Source           273 non-null    object
#  2   Destination      273 non-null    object
#  3   Route            273 non-null    object
#  4   Dep_Time         273 non-null    object
#  5   Arrival_Time     273 non-null    object
#  6   Duration         273 non-null    object
#  7   Total_Stops      273 non-null    object
#  8   Additional_Info  273 non-null    object
#  9   Price            273 non-null    int64
#  10  Date             273 non-null    int64
#  11  Month            273 non-null    int64
#  12  Year             273 non-null    int64
# dtypes: int64(4), object(9)
# memory usage: 27.9+ KB

# %%
final_df.drop('Arrival_Time',axis=1,inplace=True)

# %%
final_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time Duration  \
# 0  Jet Airways     Delhi      Cochin  DEL → AMD → BOM → COK    19:10  23h 50m
# 1    Air India     Delhi      Cochin  DEL → GOI → BOM → COK    22:00  21h 15m
# 2  Jet Airways     Delhi      Cochin  DEL → BDQ → BOM → COK    18:25  24h 25m
# 3       IndiGo  Banglore   New Delhi              BLR → DEL    18:55   2h 50m
# 4       IndiGo  Banglore   New Delhi              BLR → DEL    00:40   2h 45m
#
#   Total_Stops              Additional_Info  Price  Date  Month  Year
# 0     2 stops                      No info  15129    18      5  2019
# 1     2 stops                      No info  10441    27      6  2019
# 2     2 stops  In-flight meal not included   9270    21      3  2019
# 3    non-stop                      No info   8855     3      3  2019
# 4    non-stop                      No info   4777    24      3  2019

# %%
final_df['Dep_Time'].str.split(' ').str[0]
# Out:
# 0      19:10
# 1      22:00
# 2      18:25
# 3      18:55
# 4      00:40
#        ...
# 268    10:00
# 269    06:10
# 270    16:50
# 271    16:40
# 272    09:25
# Name: Dep_Time, Length: 273, dtype: object

# %%
final_df['Dep_Time']=final_df['Dep_Time'].str.split(' ').str[0]

# %%
final_df['Dep_hour']=final_df['Dep_Time'].str.split(':').str[0]
final_df['Dep_min']=final_df['Dep_Time'].str.split(':').str[1]

# %%
final_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time Duration  \
# 0  Jet Airways     Delhi      Cochin  DEL → AMD → BOM → COK    19:10  23h 50m
# 1    Air India     Delhi      Cochin  DEL → GOI → BOM → COK    22:00  21h 15m
# 2  Jet Airways     Delhi      Cochin  DEL → BDQ → BOM → COK    18:25  24h 25m
# 3       IndiGo  Banglore   New Delhi              BLR → DEL    18:55   2h 50m
# 4       IndiGo  Banglore   New Delhi              BLR → DEL    00:40   2h 45m
#
#   Total_Stops              Additional_Info  Price  Date  Month  Year Dep_hour  \
# 0     2 stops                      No info  15129    18      5  2019       19
# 1     2 stops                      No info  10441    27      6  2019       22
# 2     2 stops  In-flight meal not included   9270    21      3  2019       18
# 3    non-stop                      No info   8855     3      3  2019       18
# 4    non-stop                      No info   4777    24      3  2019       00
#
#   Dep_min
# 0      10
# 1      00
# 2      25
# 3      55
# 4      40

# %%
final_df['Dep_hour']=final_df['Dep_hour'].astype(int)
final_df['Dep_min']=final_df['Dep_min'].astype(int)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273 entries, 0 to 272
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          273 non-null    object
#  1   Source           273 non-null    object
#  2   Destination      273 non-null    object
#  3   Route            273 non-null    object
#  4   Dep_Time         273 non-null    object
#  5   Duration         273 non-null    object
#  6   Total_Stops      273 non-null    object
#  7   Additional_Info  273 non-null    object
#  8   Price            273 non-null    int64
#  9   Date             273 non-null    int64
#  10  Month            273 non-null    int64
#  11  Year             273 non-null    int64
#  12  Dep_hour         273 non-null    int64
#  13  Dep_min          273 non-null    int64
# dtypes: int64(6), object(8)
# memory usage: 30.0+ KB

# %%
final_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time Duration  \
# 0  Jet Airways     Delhi      Cochin  DEL → AMD → BOM → COK    19:10  23h 50m
# 1    Air India     Delhi      Cochin  DEL → GOI → BOM → COK    22:00  21h 15m
# 2  Jet Airways     Delhi      Cochin  DEL → BDQ → BOM → COK    18:25  24h 25m
# 3       IndiGo  Banglore   New Delhi              BLR → DEL    18:55   2h 50m
# 4       IndiGo  Banglore   New Delhi              BLR → DEL    00:40   2h 45m
#
#   Total_Stops              Additional_Info  Price  Date  Month  Year  \
# 0     2 stops                      No info  15129    18      5  2019
# 1     2 stops                      No info  10441    27      6  2019
# 2     2 stops  In-flight meal not included   9270    21      3  2019
# 3    non-stop                      No info   8855     3      3  2019
# 4    non-stop                      No info   4777    24      3  2019
#
#    Dep_hour  Dep_min
# 0        19       10
# 1        22        0
# 2        18       25
# 3        18       55
# 4         0       40

# %%
final_df.drop('Dep_Time',axis=1,inplace=True)

# %%
final_df.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0  Jet Airways     Delhi      Cochin  DEL → AMD → BOM → COK  23h 50m
# 1    Air India     Delhi      Cochin  DEL → GOI → BOM → COK  21h 15m
# 2  Jet Airways     Delhi      Cochin  DEL → BDQ → BOM → COK  24h 25m
# 3       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 4       IndiGo  Banglore   New Delhi              BLR → DEL   2h 45m
#
#   Total_Stops              Additional_Info  Price  Date  Month  Year  \
# 0     2 stops                      No info  15129    18      5  2019
# 1     2 stops                      No info  10441    27      6  2019
# 2     2 stops  In-flight meal not included   9270    21      3  2019
# 3    non-stop                      No info   8855     3      3  2019
# 4    non-stop                      No info   4777    24      3  2019
#
#    Dep_hour  Dep_min
# 0        19       10
# 1        22        0
# 2        18       25
# 3        18       55
# 4         0       40

# %%
final_df['Total_Stops'].unique()
# Out:
# array(['2 stops', 'non-stop', '1 stop', '3 stops'], dtype=object)

# %%
final_df['Total_Stops']=final_df['Total_Stops'].map({'non-stop':0,'1 stop':1,'2 stops':2,'3 stops':3,'4 stops':4})

# %%
final_df.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0  Jet Airways     Delhi      Cochin  DEL → AMD → BOM → COK  23h 50m
# 1    Air India     Delhi      Cochin  DEL → GOI → BOM → COK  21h 15m
# 2  Jet Airways     Delhi      Cochin  DEL → BDQ → BOM → COK  24h 25m
# 3       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 4       IndiGo  Banglore   New Delhi              BLR → DEL   2h 45m
#
#    Total_Stops              Additional_Info  Price  Date  Month  Year  \
# 0            2                      No info  15129    18      5  2019
# 1            2                      No info  10441    27      6  2019
# 2            2  In-flight meal not included   9270    21      3  2019
# 3            0                      No info   8855     3      3  2019
# 4            0                      No info   4777    24      3  2019
#
#    Dep_hour  Dep_min
# 0        19       10
# 1        22        0
# 2        18       25
# 3        18       55
# 4         0       40

# %%
final_df.drop('Route',axis=1,inplace=True)

# %%
final_df.head()
# Out:
#        Airline    Source Destination Duration  Total_Stops  \
# 0  Jet Airways     Delhi      Cochin  23h 50m            2
# 1    Air India     Delhi      Cochin  21h 15m            2
# 2  Jet Airways     Delhi      Cochin  24h 25m            2
# 3       IndiGo  Banglore   New Delhi   2h 50m            0
# 4       IndiGo  Banglore   New Delhi   2h 45m            0
#
#                Additional_Info  Price  Date  Month  Year  Dep_hour  Dep_min
# 0                      No info  15129    18      5  2019        19       10
# 1                      No info  10441    27      6  2019        22        0
# 2  In-flight meal not included   9270    21      3  2019        18       25
# 3                      No info   8855     3      3  2019        18       55
# 4                      No info   4777    24      3  2019         0       40

# %%
final_df['Additional_Info'].unique()
# Out:
# array(['No info', 'In-flight meal not included'], dtype=object)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273 entries, 0 to 272
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          273 non-null    object
#  1   Source           273 non-null    object
#  2   Destination      273 non-null    object
#  3   Duration         273 non-null    object
#  4   Total_Stops      273 non-null    int64
#  5   Additional_Info  273 non-null    object
#  6   Price            273 non-null    int64
#  7   Date             273 non-null    int64
#  8   Month            273 non-null    int64
#  9   Year             273 non-null    int64
#  10  Dep_hour         273 non-null    int64
#  11  Dep_min          273 non-null    int64
# dtypes: int64(7), object(5)
# memory usage: 25.7+ KB

# %%
final_df['Duration_hour'] = final_df['Duration'].str.split(' ').str[0].str.split('h').str[0]

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273 entries, 0 to 272
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          273 non-null    object
#  1   Source           273 non-null    object
#  2   Destination      273 non-null    object
#  3   Duration         273 non-null    object
#  4   Total_Stops      273 non-null    int64
#  5   Additional_Info  273 non-null    object
#  6   Price            273 non-null    int64
#  7   Date             273 non-null    int64
#  8   Month            273 non-null    int64
#  9   Year             273 non-null    int64
#  10  Dep_hour         273 non-null    int64
#  11  Dep_min          273 non-null    int64
#  12  Duration_hour    273 non-null    int64
#  13  Duration_min     273 non-null    int64
# dtypes: int64(9), object(5)
# memory usage: 30.0+ KB

# %%
final_df['duration_hour']=final_df['Duration_hour'].astype('int')

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273 entries, 0 to 272
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          273 non-null    object
#  1   Source           273 non-null    object
#  2   Destination      273 non-null    object
#  3   Duration         273 non-null    object
#  4   Total_Stops      273 non-null    int64
#  5   Additional_Info  273 non-null    object
#  6   Price            273 non-null    int64
#  7   Date             273 non-null    int64
#  8   Month            273 non-null    int64
#  9   Year             273 non-null    int64
#  10  Dep_hour         273 non-null    int64
#  11  Dep_min          273 non-null    int64
#  12  Duration_hour    273 non-null    int64
#  13  Duration_min     273 non-null    int64
#  14  duration_hour    273 non-null    int64
# dtypes: int64(10), object(5)
# memory usage: 32.1+ KB

# %%
final_df.drop('Duration',axis=1,inplace=True)

# %%
final_df.head()
# Out:
#        Airline    Source Destination  Total_Stops  \
# 0  Jet Airways     Delhi      Cochin            2
# 1    Air India     Delhi      Cochin            2
# 2  Jet Airways     Delhi      Cochin            2
# 3       IndiGo  Banglore   New Delhi            0
# 4       IndiGo  Banglore   New Delhi            0
#
#                Additional_Info  Price  Date  Month  Year  Dep_hour  Dep_min  \
# 0                      No info  15129    18      5  2019        19       10
# 1                      No info  10441    27      6  2019        22        0
# 2  In-flight meal not included   9270    21      3  2019        18       25
# 3                      No info   8855     3      3  2019        18       55
# 4                      No info   4777    24      3  2019         0       40
#
#    Duration_min  duration_hour
# 0            50             23
# 1            15             21
# 2            25             24
# 3            50              2
# 4            45              2

# %%
final_df['Airline'].unique()
# Out:
# array(['Jet Airways', 'Air India', 'IndiGo', 'Multiple carriers', 'GoAir',
#        'Air Asia', 'SpiceJet', 'Vistara'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()

# %%
final_df['Airline']=labelencoder.fit_transform(final_df['Airline'])
final_df['Source']=labelencoder.fit_transform(final_df['Source'])
final_df['Destination']=labelencoder.fit_transform(final_df['Destination'])
final_df['Additional_Info']=labelencoder.fit_transform(final_df['Additional_Info'])

# %%
final_df.shape
# Out:
# (273, 13)

# %%
final_df.head()
# Out:
#    Airline  Source  Destination  Total_Stops  Additional_Info  Price  Date  \
# 0        4       1            1            2                1  15129    18
# 1        1       1            1            2                1  10441    27
# 2        4       1            1            2                0   9270    21
# 3        3       0            2            0                1   8855     3
# 4        3       0            2            0                1   4777    24
#
#    Month  Year  Dep_hour  Dep_min  Duration_min  duration_hour
# 0      5  2019        19       10            50             23
# 1      6  2019        22        0            15             21
# 2      3  2019        18       25            25             24
# 3      3  2019        18       55            50              2
# 4      3  2019         0       40            45              2

# %%
c
